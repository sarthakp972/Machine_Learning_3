# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakp972/Machine_Learning_3/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
actual_df=pd.read_csv('/content/drive/MyDrive/Machine_learning_15 01 2024/Salary_Dataset.csv')

# %%
df=actual_df
df
# Out:
#       country    Salary  YearsExperience Purchased
# 0       Dubai   39343.0              1.1        No
# 1      Canada   46205.0              1.3       Yes
# 2      Canada   37731.0              1.5        No
# 3      Canada   43525.0              2.0        No
# 4         USA   39891.0              2.2        No
# 5       Dubai   56642.0              2.9        No
# 6      Canada   60150.0              3.0       Yes
# 7   Australia   54445.0              3.2        No
# 8       Dubai   64445.0              3.2       Yes
# 9       Dubai   57189.0              3.7        No
# 10      Dubai   63218.0              3.9       Yes
# 11        USA   55794.0              4.0        No
# 12      Dubai   56957.0              4.0       Yes
# 13     Canada   57081.0              4.1        No
# 14  Australia   61111.0              4.5        No
# 15        USA   67938.0              4.9        No
# 16        USA   66029.0              5.1        No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          30 non-null     object
#  1   Salary           30 non-null     float64
#  2   YearsExperience  30 non-null     float64
#  3   Purchased        30 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.1+ KB

# %%
df.shape
# Out:
# (30, 4)

# %% [markdown]
# #categorical coums
#
# 1. Country - multiple categories - one hot Encoding
# 2. Purchased - 2 Categories - Label Encoding

# %%
# one hot Encoding using pandas
country_dummy= pd.get_dummies(df['country']) # contiouns convert categoris and categoris convert into binary
country_dummy # make sapret data fram
# Out:
#     Australia  Canada  Dubai  USA
# 0           0       0      1    0
# 1           0       1      0    0
# 2           0       1      0    0
# 3           0       1      0    0
# 4           0       0      0    1
# 5           0       0      1    0
# 6           0       1      0    0
# 7           1       0      0    0
# 8           0       0      1    0
# 9           0       0      1    0
# 10          0       0      1    0
# 11          0       0      0    1
# 12          0       0      1    0
# 13          0       1      0    0
# 14          1       0      0    0
# 15          0       0      0    1
# 16          0       0      0    1
# 17          0       1      0    0
# 18          1       0      0    0
# 19          0       1      0    0
# 20          0       1      0    0
# 21          1       0      0    0
# 22          1       0      0    0
# 23          1       0      0    0
# 24          0       0      1    0
# 25          1       0      0    0
# ...

# %%
df=pd.concat([df,country_dummy],axis=1)
df
# Out:
#       country    Salary  YearsExperience Purchased  Australia  Canada  Dubai  \
# 0       Dubai   39343.0              1.1        No          0       0      1
# 1      Canada   46205.0              1.3       Yes          0       1      0
# 2      Canada   37731.0              1.5        No          0       1      0
# 3      Canada   43525.0              2.0        No          0       1      0
# 4         USA   39891.0              2.2        No          0       0      0
# 5       Dubai   56642.0              2.9        No          0       0      1
# 6      Canada   60150.0              3.0       Yes          0       1      0
# 7   Australia   54445.0              3.2        No          1       0      0
# 8       Dubai   64445.0              3.2       Yes          0       0      1
# 9       Dubai   57189.0              3.7        No          0       0      1
# 10      Dubai   63218.0              3.9       Yes          0       0      1
# ...

# %%
df.drop('country',axis=1,inplace=True)#delete the coloumn country
df
# Out:
#       Salary  YearsExperience Purchased  Australia  Canada  Dubai  USA
# 0    39343.0              1.1        No          0       0      1    0
# 1    46205.0              1.3       Yes          0       1      0    0
# 2    37731.0              1.5        No          0       1      0    0
# 3    43525.0              2.0        No          0       1      0    0
# 4    39891.0              2.2        No          0       0      0    1
# 5    56642.0              2.9        No          0       0      1    0
# 6    60150.0              3.0       Yes          0       1      0    0
# 7    54445.0              3.2        No          1       0      0    0
# 8    64445.0              3.2       Yes          0       0      1    0
# 9    57189.0              3.7        No          0       0      1    0
# 10   63218.0              3.9       Yes          0       0      1    0
# 11   55794.0              4.0        No          0       0      0    1
# ...

# %%
df.columns
# Out:
# Index(['Salary', 'YearsExperience', 'Purchased', 'Australia', 'Canada',
#        'Dubai', 'USA'],
#       dtype='object')

# %%
dataset=df[['Australia','Canada','Dubai', 'USA','Salary', 'YearsExperience','Purchased',]]
dataset
# Out:
#     Australia  Canada  Dubai  USA    Salary  YearsExperience Purchased
# 0           0       0      1    0   39343.0              1.1        No
# 1           0       1      0    0   46205.0              1.3       Yes
# 2           0       1      0    0   37731.0              1.5        No
# 3           0       1      0    0   43525.0              2.0        No
# 4           0       0      0    1   39891.0              2.2        No
# 5           0       0      1    0   56642.0              2.9        No
# 6           0       1      0    0   60150.0              3.0       Yes
# 7           1       0      0    0   54445.0              3.2        No
# 8           0       0      1    0   64445.0              3.2       Yes
# 9           0       0      1    0   57189.0              3.7        No
# 10          0       0      1    0   63218.0              3.9       Yes
# 11          0       0      0    1   55794.0              4.0        No
# ...

# %%
actual_df
# Out:
#       country    Salary  YearsExperience Purchased
# 0       Dubai   39343.0              1.1        No
# 1      Canada   46205.0              1.3       Yes
# 2      Canada   37731.0              1.5        No
# 3      Canada   43525.0              2.0        No
# 4         USA   39891.0              2.2        No
# 5       Dubai   56642.0              2.9        No
# 6      Canada   60150.0              3.0       Yes
# 7   Australia   54445.0              3.2        No
# 8       Dubai   64445.0              3.2       Yes
# 9       Dubai   57189.0              3.7        No
# 10      Dubai   63218.0              3.9       Yes
# 11        USA   55794.0              4.0        No
# 12      Dubai   56957.0              4.0       Yes
# 13     Canada   57081.0              4.1        No
# 14  Australia   61111.0              4.5        No
# 15        USA   67938.0              4.9        No
# 16        USA   66029.0              5.1        No
# ...

# %%
le=LabelEncoder()
actual_df['Purchased']=le.fit_transform(actual_df['Purchased'])
actual_df
# Out:
#       country    Salary  YearsExperience  Purchased
# 0       Dubai   39343.0              1.1          0
# 1      Canada   46205.0              1.3          1
# 2      Canada   37731.0              1.5          0
# 3      Canada   43525.0              2.0          0
# 4         USA   39891.0              2.2          0
# 5       Dubai   56642.0              2.9          0
# 6      Canada   60150.0              3.0          1
# 7   Australia   54445.0              3.2          0
# 8       Dubai   64445.0              3.2          1
# 9       Dubai   57189.0              3.7          0
# 10      Dubai   63218.0              3.9          1
# 11        USA   55794.0              4.0          0
# 12      Dubai   56957.0              4.0          1
# 13     Canada   57081.0              4.1          0
# 14  Australia   61111.0              4.5          0
# 15        USA   67938.0              4.9          0
# 16        USA   66029.0              5.1          0
# ...
